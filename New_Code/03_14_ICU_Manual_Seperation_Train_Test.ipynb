# %%
import pandas as pd
import numpy as np

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o31_ICU_final.csv')

# %%
df_icu
# Out:
#       Department  subject_id   hadm_id        date      time  \
# 0            ICU    10004733  27411876  2174-12-04  08:00:00
# 1            ICU    10004733  27411876  2174-12-04  16:00:00
# 2            ICU    10004733  27411876  2174-12-05  00:00:00
# 3            ICU    10004733  27411876  2174-12-05  08:00:00
# 4            ICU    10004733  27411876  2174-12-05  16:00:00
# ...          ...         ...       ...         ...       ...
# 90812        ICU    19999987  23865745  2145-11-04  16:00:00
# 90813        ICU    19999987  23865745  2145-11-05  00:00:00
# 90814        ICU    19999987  23865745  2145-11-06  08:00:00
# 90815        ICU    19999987  23865745  2145-11-07  00:00:00
# 90816        ICU    19999987  23865745  2145-11-09  00:00:00
#
#        Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 0             93.200000                    19.800000
# 1             97.250000                    19.250000
# 2            100.333333                    24.222222
# 3             90.687500                    20.312500
# 4             92.111111                    14.000000
# ...                 ...                          ...
# 90812         92.500000                    22.250000
# 90813               NaN                          NaN
# 90814               NaN                          NaN
# 90815               NaN                          NaN
# 90816               NaN                          NaN
#
#        O2 saturation pulseoxymetry (%)  \
# 0                            98.800000
# 1                            96.875000
# 2                            94.444444
# 3                            95.031250
# 4                            96.777778
# ...                                ...
# 90812                        98.750000
# 90813                              NaN
# 90814                              NaN
# 90815                              NaN
# 90816                              NaN
#
#        Non Invasive Blood Pressure systolic (mmHg)  \
# 0                                       170.750000
# 1                                       153.125000
# 2                                       154.666667
# 3                                       147.031250
# 4                                       148.555556
# ...                                            ...
# 90812                                   152.666667
# 90813                                          NaN
# 90814                                          NaN
# 90815                                          NaN
# 90816                                          NaN
#
#        Non Invasive Blood Pressure diastolic (mmHg)  ...  \
# 0                                        103.250000  ...
# 1                                         90.250000  ...
# 2                                         75.777778  ...
# 3                                         67.437500  ...
# 4                                         73.666667  ...
# ...                                             ...  ...
# 90812                                    106.333333  ...
# 90813                                           NaN  ...
# 90814                                           NaN  ...
# 90815                                           NaN  ...
# 90816                                           NaN  ...
#
#        Plasma (Cerebrospinal Fluid)  Polys (Cerebrospinal Fluid)  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 90812                           NaN                          NaN
# 90813                           NaN                          NaN
# 90814                           NaN                          NaN
# 90815                           NaN                          NaN
# 90816                           NaN                          NaN
#
#        Promyelocytes (Cerebrospinal Fluid)  RBC, CSF (Cerebrospinal Fluid)  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# ...                                    ...                             ...
# 90812                                  NaN                             NaN
# 90813                                  NaN                             NaN
# 90814                                  NaN                             NaN
# 90815                                  NaN                             NaN
# 90816                                  NaN                             NaN
#
#        Total Nucleated Cells, CSF (Cerebrospinal Fluid)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 90812                                               NaN
# 90813                                               NaN
# 90814                                               NaN
# 90815                                               NaN
# 90816                                               NaN
#
#        Total Nucleated Cells, Joint (Joint Fluid)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 90812                                         NaN
# 90813                                         NaN
# 90814                                         NaN
# 90815                                         NaN
# 90816                                         NaN
#
#        Total Nucleated Cells, Other (Other Body Fluid)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 90812                                              NaN
# 90813                                              NaN
# 90814                                              NaN
# 90815                                              NaN
# 90816                                              NaN
#
#        Total Nucleated Cells, Pleural (Pleural)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 90812                                       NaN
# 90813                                       NaN
# 90814                                       NaN
# 90815                                       NaN
# 90816                                       NaN
#
#        Absolute Lymphocyte Count (Blood).1  hospital_expire_flag
# 0                                      NaN              survival
# 1                                      NaN              survival
# 2                                      NaN              survival
# 3                                      NaN              survival
# 4                                      NaN              survival
# ...                                    ...                   ...
# 90812                                  NaN              survival
# 90813                                  NaN              survival
# 90814                                  NaN              survival
# 90815                                  NaN              survival
# 90816                                  NaN              survival
#
# [90817 rows x 1101 columns]

# %%
df_1 = df_icu.iloc[:63568,:]
df_2 = df_icu.iloc[63568:,:]

# %%
df_1.to_csv('D:\Thesis\Weka\Train_Test_Sets\Sorted Set\Train_70.csv', index=False)
df_2.to_csv('D:\Thesis\Weka\Train_Test_Sets\Sorted Set\Test_30.csv', index=False)
