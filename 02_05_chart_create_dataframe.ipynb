# %%
"""
Δημιουργία του πίνακα chartevet με το είδος των εξετάσων διαχωρισμένες σε 707 στήλες.
"""
# Out:
# '\nΔημιουργία του πίνακα chartevet με το είδος των εξετάσων διαχωρισμένες σε 707 στήλες.\n'

# %%
#Εισαγωγή βιβλιοθήκης Panda
import pandas as pd

# %%
#Δημιουργώ τις στήλες από το αρχείο που περιλαμβάνει τις μοναδικές εξετάσεις
df_columns = pd.read_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\o9_cerebral_infarction_chartevents_counts_with_labels.csv',
                         usecols = ['label'], index_col=False)

#Ορίζω το header ως index έτσι ώστε όταν αλλάξω την κατεύθυνση του csv να μπουν τα στοιχεία στην κεφαλίδα.
df_columns = df_columns.set_index('label')

# Μεταφέρω τις γραμμές σε στήλες
df_columns = df_columns.transpose()

# Αδειάζω την μία και μοναδική γραμμή του πίνακα η οποία αποτύπωνε το πόσες φορές έκαναν την εμφάνιση τους οι εξετάσεις.
#df_columns = df_columns.drop(['times'])

# %%
df_rows = pd.read_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\o9_charttime_8_hour_mean_item_merged.csv')
# Out:
# C:\Users\Dimopoulos\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Μετατροπή της στήλης charttime από object σε datetime για να μπορέσει να γίνει ο παρακάτω διαχωρισμός σε δυο στήλες
df_rows['charttime']= pd.to_datetime(df_rows['charttime'])

# %%
#Διαχωρισμός σε δυο καινούργιες στήλες της ημερομηνίας και ώρας
df_rows['date'] = pd.to_datetime(df_rows['charttime']).dt.date
df_rows['time'] = pd.to_datetime(df_rows['charttime']).dt.time

# %%
#Αλλαγή της σειράς εμφάνισης των στοιχείων του dataframe, για να είναι ευανάγνωστο κατά τους ελέγχους μου,
#δεν είναι απαραίτητο για την εξέλιξη του κώδικα
df_rows = df_rows[['subject_id', 'hadm_id', 'charttime', 'date', 'time', 'itemid', 'Mean_Chart']]

# %%
df_rows.to_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\o9_cerebral_infarction_chartevents_grouped_8hours_date_time.csv', index=False)

# %%
# Εδώ παίρνουμε τις τιμές της στήλης time και βλέπουμε πως γκρουπάρονται οι ώρες.
# Οπ΄ότε έχουμε τρία οχτάωρα 00:00, 08:00 και 16:00
list(set(df_rows['time']))
# Out:
# [datetime.time(0, 0), datetime.time(8, 0), datetime.time(16, 0)]

# %%
# Απλά προβάλω τις στήλες των καταγραφών
df_columns
# Out:
# Empty DataFrame
# Columns: [Heart Rate, Heart rate Alarm - High, Heart Rate Alarm - Low, Arterial Blood Pressure systolic, Arterial Blood Pressure diastolic, Arterial Blood Pressure mean, Arterial Blood Pressure Alarm - Low, Arterial Blood Pressure Alarm - High, Pulmonary Artery Pressure systolic, Pulmonary Artery Pressure diastolic, Pulmonary Artery Pressure mean, Pulmonary Artery Pressure Alarm - High, Pulmonary Artery Pressure Alarm - Low, Central Venous Pressure Alarm - High, Central Venous Pressure  Alarm - Low, Central Venous Pressure, Cardiac Output (thermodilution), Right Ventricular Assist Device Flow, Non Invasive Blood Pressure systolic, Non Invasive Blood Pressure diastolic, Non Invasive Blood Pressure mean, Temporary AV interval, Respiratory Rate, Arterial O2 pressure, Arterial O2 Saturation, Hemoglobin, Arterial CO2 Pressure, CO2 production, PH (Venous), O2 saturation pulseoxymetry, Resistance, Minute Volume Alarm - Low, Minute Volume Alarm - High, PEEP set, Activated Clotting Time, Hematocrit (serum), WBC, Ammonia, Amylase, AST, Chloride (serum), Cholesterol, Creatinine (serum), Glucose (serum), HDL, LDH, Magnesium, ALT, Sodium (serum), Total Protein, PH (dipstick), GCS - Eye Opening, Intra Cranial Pressure, QTc, TCO2 (calc) Venous, Non-Invasive Blood Pressure Alarm - High, Non-Invasive Blood Pressure Alarm - Low, Temperature Fahrenheit, Temperature Celsius, Bladder Pressure, Orthostatic HR lying, Orthostatic HR sitting, Orthostatic BPs standing, Intra Cranial Pressure Alarm - High, Intra Cranial Pressure Alarm - Low, O2 Saturation Pulseoxymetry Alarm - High, O2 Saturation Pulseoxymetry Alarm - Low, PCWP, SvO2, PA Line cm Mark, VAD Beat Rate R, Pain Level, Nausea and Vomiting (CIWA), Tremor (CIWA), Paroxysmal Sweats, Anxiety, Auditory Disturbance, Agitation, Tactile Disturbances, Visual Disturbances, Headache, Orient/Clouding Sensory, PH (Arterial), O2 Flow, Inspired O2 Fraction, Ventilator Type, Ventilator Mode, Inspired Gas Temp., Paw High, Vti High, Fspn High, Apnea Interval, GCS - Verbal Response, GCS - Motor Response, Temporary Venticular Sens Threshold mV, Temporary Venticular Stim Threshold mA, Temporary Pacemaker Wires Venticular, Temporary Pacemaker Wires Ground, Braden Sensory Perception, Braden Moisture, ...]
# Index: []
#
# [0 rows x 707 columns]

# %%
"""
Δημιουργώ ένα μοναδικό αναγνωριστικό με την ένωση των
στοιχείων από στήλες subject, hadm_id, date και time.
Ανάμεσα στα στοιχεία προβάλω ένα κενό το οποίο θα μου
φανεί χρήσιμο αργότερα για τον διαχωρισμό τους ξανά σε
διαφορετικές στήλες.
"""
df_rows["concat"] = (df_rows["subject_id"].astype(str)
                     +" "
                     +df_rows["hadm_id"].astype(str)
                     +" "
                     +df_rows["date"].astype(str)
                     +" "+
                     df_rows["time"].astype(str))

# %%
# Ελέγχω αν υπάρχει κενό κελί στην στήλη concat.
df_rows['concat'].isnull().values.any()
# Out:
# False

# %%
# Αλλάζω την σειρά των στηλών του dataframe
df_rows = df_rows[['concat', 'subject_id', 'hadm_id', 'charttime', 'date', 'time', 'itemid', 'Mean_Chart']]

# %%
# Από το dr_rows κρατάω τις μοναδικές εγγραφές
df_copy_rows = pd.DataFrame(df_rows.concat.unique())

# Δημιουργώ καινούργιο πίνακα ενσωματώνοντας στον πίνακα df columns τις στήλες με τις κενές για την ώρα εξετάσεις
chart_tbl = pd.concat([df_copy_rows, df_columns], axis=1)

# Μετονομάζω την στήλη 0 σε concat για να είναι ίδιες στους δυο πίνακες
chart_tbl = chart_tbl.rename({0:'concat'}, axis=1)

# %%
#Διαχωρισμός του concat σε τέσσερις στήλες
chart_tbl[['subject_id','hadm_id', 'date', 'time']] = chart_tbl['concat'].str.split(expand=True)

# %%
#Διαγράφω την στήλη concat γιατί θα πρέπει να την ξαναδημιουργήσω
#χωρίς κενά ανάμεσα στα ενοποιημένα στοιχεία, οπότε θα την έχω διπλή.
chart_tbl = chart_tbl.drop('concat', 1)

# %%
chart_tbl
# Out:
#        Heart Rate  Heart rate Alarm - High  Heart Rate Alarm - Low  \
# 0             NaN                      NaN                     NaN
# 1             NaN                      NaN                     NaN
# 2             NaN                      NaN                     NaN
# 3             NaN                      NaN                     NaN
# 4             NaN                      NaN                     NaN
# ...           ...                      ...                     ...
# 65184         NaN                      NaN                     NaN
# 65185         NaN                      NaN                     NaN
# 65186         NaN                      NaN                     NaN
# 65187         NaN                      NaN                     NaN
# 65188         NaN                      NaN                     NaN
#
#        Arterial Blood Pressure systolic  Arterial Blood Pressure diastolic  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 65184                               NaN                                NaN
# 65185                               NaN                                NaN
# 65186                               NaN                                NaN
# 65187                               NaN                                NaN
# 65188                               NaN                                NaN
#
#        Arterial Blood Pressure mean  Arterial Blood Pressure Alarm - Low  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 65184                           NaN                                  NaN
# 65185                           NaN                                  NaN
# 65186                           NaN                                  NaN
# 65187                           NaN                                  NaN
# 65188                           NaN                                  NaN
#
#        Arterial Blood Pressure Alarm - High  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 65184                                   NaN
# 65185                                   NaN
# 65186                                   NaN
# 65187                                   NaN
# 65188                                   NaN
#
#        Pulmonary Artery Pressure systolic  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 65184                                 NaN
# 65185                                 NaN
# 65186                                 NaN
# 65187                                 NaN
# 65188                                 NaN
#
#        Pulmonary Artery Pressure diastolic  ...  HM II- Flow  \
# 0                                      NaN  ...          NaN
# 1                                      NaN  ...          NaN
# 2                                      NaN  ...          NaN
# 3                                      NaN  ...          NaN
# 4                                      NaN  ...          NaN
# ...                                    ...  ...          ...
# 65184                                  NaN  ...          NaN
# 65185                                  NaN  ...          NaN
# 65186                                  NaN  ...          NaN
# 65187                                  NaN  ...          NaN
# 65188                                  NaN  ...          NaN
#
#        HM II- Speed (RPM)  HM II- PI  HM II- Power  \
# 0                     NaN        NaN           NaN
# 1                     NaN        NaN           NaN
# 2                     NaN        NaN           NaN
# 3                     NaN        NaN           NaN
# 4                     NaN        NaN           NaN
# ...                   ...        ...           ...
# 65184                 NaN        NaN           NaN
# 65185                 NaN        NaN           NaN
# 65186                 NaN        NaN           NaN
# 65187                 NaN        NaN           NaN
# 65188                 NaN        NaN           NaN
#
#        Activity / Mobility (JH-HLM)  Absolute Neutrophil Count  subject_id  \
# 0                               NaN                        NaN    10004733
# 1                               NaN                        NaN    10004733
# 2                               NaN                        NaN    10004733
# 3                               NaN                        NaN    10004733
# 4                               NaN                        NaN    10004733
# ...                             ...                        ...         ...
# 65184                           NaN                        NaN    10546885
# 65185                           NaN                        NaN    11114858
# 65186                           NaN                        NaN    19623640
# 65187                           NaN                        NaN    11974151
# 65188                           NaN                        NaN    17589641
#
#         hadm_id        date      time
# 0      27411876  2174-12-04  08:00:00
# 1      27411876  2174-12-04  16:00:00
# 2      27411876  2174-12-05  00:00:00
# 3      27411876  2174-12-05  08:00:00
# 4      27411876  2174-12-05  16:00:00
# ...         ...         ...       ...
# 65184  25213587  2174-09-29  08:00:00
# 65185  24037757  2128-08-12  08:00:00
# 65186  29398204  2168-04-01  16:00:00
# 65187  22782098  2152-07-02  16:00:00
# 65188  25678885  2161-09-02  16:00:00
#
# [65189 rows x 711 columns]

# %%
# Εξαγωγή του άδειου πίνακα για να τον γεμίσουμε στο επόμενο στάδιο
chart_tbl.to_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\o9_empty_chart_tbl.csv', index=False)
