# %%
"""
Δημιουργία του πίνακα chartevet
με το είδος των εξετάσων διαχωρισμένες
σε 707 στήλες.
"""

# %%
import pandas as pd

# %%
df_rows = pd.read_csv('D:\Thesis\exports\o9_chartevent_8_hour_mean.csv')

# %%
df_rows
# Out:
#          subject_id   hadm_id  itemid            charttime  Mean_Chart  \
# 0          10000980  26913865  220045  2189-06-27 08:00:00   73.125000
# 1          10000980  26913865  220045  2189-06-27 16:00:00   75.000000
# 2          10000980  26913865  220179  2189-06-27 08:00:00  146.625000
# 3          10000980  26913865  220179  2189-06-27 16:00:00  131.333333
# 4          10000980  26913865  220180  2189-06-27 08:00:00   86.500000
# ...             ...       ...     ...                  ...         ...
# 6746005    19997473  27787494  229326  2173-09-19 16:00:00    0.000000
# 6746006    19997473  27787494  229326  2173-09-20 08:00:00    0.000000
# 6746007    19997473  27787494  229326  2173-09-20 16:00:00    0.000000
# 6746008    19997473  27787494  229326  2173-09-21 08:00:00    0.000000
# 6746009    19997473  27787494  229326  2173-09-21 16:00:00    0.000000
#
#                date      time
# 0        2189-06-27  08:00:00
# 1        2189-06-27  16:00:00
# 2        2189-06-27  08:00:00
# 3        2189-06-27  16:00:00
# 4        2189-06-27  08:00:00
# ...             ...       ...
# 6746005  2173-09-19  16:00:00
# 6746006  2173-09-20  08:00:00
# 6746007  2173-09-20  16:00:00
# 6746008  2173-09-21  08:00:00
# 6746009  2173-09-21  16:00:00
#
# [6746010 rows x 7 columns]

# %%
# Εδώ παίρνουμε τις τιμές της στήλης time και βλέπουμε πως γκρουπάρονται οι ώρες.
# Οπ΄ότε έχουμε τρία οχτάωρα 00:00, 08:00 και 16:00
list(set(df_rows['time']))
# Out:
# ['16:00:00', '08:00:00', '00:00:00']

# %%
#Δημιουργώ τις στήλες από το αρχείο που περιλαμβάνει τις μοναδικές εξετάσεις
df_columns = pd.read_csv('D:\Thesis\exports\o8_chartevents_counts.csv',
                         usecols = ['itemid'], index_col=False)

#Ορίζω το header ως index έτσι ώστε όταν αλλάξω την κατεύθυνση του csv να μπουν τα στοιχεία στην κεφαλίδα.
df_columns = df_columns.set_index('itemid')

# Μεταφέρω τις γραμμές σε στήλες
df_columns = df_columns.transpose()

# %%
df_columns
# Out:
# Empty DataFrame
# Columns: [220045, 220210, 220277, 220181, 220179, 220180, 220052, 220050, 220051, 224641, 224168, 229381, 223761, 229321, 220739, 223900, 223901, 228096, 220074, 225664, 228299, 223835, 228305, 224054, 224055, 224057, 224056, 224058, 224059, 220339, 223834, 224687, 220060, 220059, 228412, 228409, 224697, 228410, 228411, 220061, 224685, 224695, 224689, 220292, 220293, 223873, 223876, 227342, 227341, 227343, 227345, 227344, 227346, 223874, 224690, 220047, 220046, 223770, 223791, 223769, 224161, 224162, 223875, 226253, 227368, 226138, 227442, 220228, 220645, 223762, 220602, 220545, 220615, 225624, 227443, 227073, 220635, 220621, 225312, 228100, 225309, 225310, 226113, 223872, 226107, 223752, 223751, 227457, 225677, 225625, 223830, 220546, 223849, 220224, 220235, 224828, 225698, 227466, 226169, 224688, ...]
# Index: []
#
# [0 rows x 901 columns]

# %%
"""
Δημιουργώ ένα μοναδικό αναγνωριστικό με την ένωση των
στοιχείων από στήλες subject, hadm_id, date και time.
Ανάμεσα στα στοιχεία προβάλω ένα κενό το οποίο θα μου
φανεί χρήσιμο αργότερα για τον διαχωρισμό τους ξανά σε
διαφορετικές στήλες.
"""
df_rows["concat"] = (df_rows["subject_id"].astype(str)
                     +" "
                     +df_rows["hadm_id"].astype(str)
                     +" "
                     +df_rows["date"].astype(str)
                     +" "+
                     df_rows["time"].astype(str))

# %%
df_rows
# Out:
#          subject_id   hadm_id  itemid            charttime  Mean_Chart  \
# 0          10000980  26913865  220045  2189-06-27 08:00:00   73.125000
# 1          10000980  26913865  220045  2189-06-27 16:00:00   75.000000
# 2          10000980  26913865  220179  2189-06-27 08:00:00  146.625000
# 3          10000980  26913865  220179  2189-06-27 16:00:00  131.333333
# 4          10000980  26913865  220180  2189-06-27 08:00:00   86.500000
# ...             ...       ...     ...                  ...         ...
# 6746005    19997473  27787494  229326  2173-09-19 16:00:00    0.000000
# 6746006    19997473  27787494  229326  2173-09-20 08:00:00    0.000000
# 6746007    19997473  27787494  229326  2173-09-20 16:00:00    0.000000
# 6746008    19997473  27787494  229326  2173-09-21 08:00:00    0.000000
# 6746009    19997473  27787494  229326  2173-09-21 16:00:00    0.000000
#
#                date      time                                 concat
# 0        2189-06-27  08:00:00  10000980 26913865 2189-06-27 08:00:00
# 1        2189-06-27  16:00:00  10000980 26913865 2189-06-27 16:00:00
# 2        2189-06-27  08:00:00  10000980 26913865 2189-06-27 08:00:00
# 3        2189-06-27  16:00:00  10000980 26913865 2189-06-27 16:00:00
# 4        2189-06-27  08:00:00  10000980 26913865 2189-06-27 08:00:00
# ...             ...       ...                                    ...
# 6746005  2173-09-19  16:00:00  19997473 27787494 2173-09-19 16:00:00
# 6746006  2173-09-20  08:00:00  19997473 27787494 2173-09-20 08:00:00
# 6746007  2173-09-20  16:00:00  19997473 27787494 2173-09-20 16:00:00
# 6746008  2173-09-21  08:00:00  19997473 27787494 2173-09-21 08:00:00
# 6746009  2173-09-21  16:00:00  19997473 27787494 2173-09-21 16:00:00
#
# [6746010 rows x 8 columns]

# %%
# Ελέγχω αν υπάρχει κενό κελί στην στήλη concat.
df_rows['concat'].isnull().values.any()
# Out:
# False

# %%
# Αλλάζω την σειρά των στηλών του dataframe
df_rows = df_rows[['concat', 'subject_id', 'hadm_id', 'charttime', 'date', 'time', 'itemid', 'Mean_Chart']]

# %%
# Από το dr_rows κρατάω τις μοναδικές εγγραφές
df_copy_rows = pd.DataFrame(df_rows.concat.unique())

# Δημιουργώ καινούργιο πίνακα ενσωματώνοντας στον πίνακα df columns τις στήλες με τις κενές για την ώρα εξετάσεις
chart_tbl = pd.concat([df_copy_rows, df_columns], axis=1)

# Μετονομάζω την στήλη 0 σε concat για να είναι ίδιες στους δυο πίνακες
chart_tbl = chart_tbl.rename({0:'concat'}, axis=1)

# %%
chart_tbl
# Out:
#                                       concat  220045  220210  220277  220181  \
# 0      10000980 26913865 2189-06-27 08:00:00     NaN     NaN     NaN     NaN
# 1      10000980 26913865 2189-06-27 16:00:00     NaN     NaN     NaN     NaN
# 2      10000980 26913865 2189-06-27 00:00:00     NaN     NaN     NaN     NaN
# 3      10002155 23822395 2129-08-04 08:00:00     NaN     NaN     NaN     NaN
# 4      10002155 23822395 2129-08-04 16:00:00     NaN     NaN     NaN     NaN
# ...                                      ...     ...     ...     ...     ...
# 96795  19997473 27787494 2173-09-20 16:00:00     NaN     NaN     NaN     NaN
# 96796  19997473 27787494 2173-09-21 00:00:00     NaN     NaN     NaN     NaN
# 96797  19997473 27787494 2173-09-21 08:00:00     NaN     NaN     NaN     NaN
# 96798  19997473 27787494 2173-09-21 16:00:00     NaN     NaN     NaN     NaN
# 96799  19997473 27787494 2173-09-22 00:00:00     NaN     NaN     NaN     NaN
#
#        220179  220180  220052  220050  220051  ...  226982  226984  226991  \
# 0         NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 1         NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2         NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 3         NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 4         NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# ...       ...     ...     ...     ...     ...  ...     ...     ...     ...
# 96795     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 96796     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 96797     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 96798     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 96799     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
#        226990  227024  227035  227037  227036  227038  226999
# 0         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4         NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...       ...     ...     ...     ...     ...     ...     ...
# 96795     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96796     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96797     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96798     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96799     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [96800 rows x 902 columns]

# %%
#Διαχωρισμός του concat σε τέσσερις στήλες
chart_tbl[['subject_id','hadm_id', 'date', 'time']] = chart_tbl['concat'].str.split(expand=True)

# %%
"""
Διαγράφω την στήλη concat γιατί θα
πρέπει να την ξαναδημιουργήσω χωρίς
κενά ανάμεσα στα ενοποιημένα στοιχεία,
οπότε θα την έχω διπλή.
"""
chart_tbl = chart_tbl.drop('concat', 1)

# %%
# Εξαγωγή του άδειου πίνακα
chart_tbl.to_csv('D:\Thesis\exports\o10_empty_chart_tbl.csv', index=False)
