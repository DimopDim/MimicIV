# %% [markdown]
# ## Εισαγωγή στήλης θνησιμότητας στην ICU

# %%
import pandas as pd
import numpy as np

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o20_ICU_merged_chart_lab.csv')

df_death= pd.read_csv('D:\Thesis\mimic-iv-1.0\core\Admissions.csv.gz', usecols = ['subject_id', 'hadm_id', 'hospital_expire_flag'])

df_death = df_death.loc[df_death['hospital_expire_flag'] == 1]

# %%
df_death
# Out:
#         subject_id   hadm_id  hospital_expire_flag
# 344       12585214  26152521                     1
# 484       19277681  23931925                     1
# 573       14659585  24219030                     1
# 758       19297170  29732017                     1
# 858       15745369  20349939                     1
# ...            ...       ...                   ...
# 523449    15152579  26248295                     1
# 523451    15543664  29639411                     1
# 523539    15476956  22615825                     1
# 523600    10746298  21643256                     1
# 523613    15724368  20127441                     1
#
# [9350 rows x 3 columns]

# %%
# Ενοποιώ τα dataframes του συνολικού πίνακα με της θνησιμότητας.

df_rslt=pd.merge(df_icu, df_death, on=['subject_id','hadm_id'],
              how="left", suffixes=('', '_delme'))

# %%
df_rslt
# Out:
#        Department  subject_id   hadm_id        date      time  \
# 0             ICU    10000980  26913865  2189-06-27  08:00:00
# 1             ICU    10000980  26913865  2189-06-27  16:00:00
# 2             ICU    10000980  26913865  2189-06-27  00:00:00
# 3             ICU    10002155  23822395  2129-08-04  08:00:00
# 4             ICU    10002155  23822395  2129-08-04  16:00:00
# ...           ...         ...       ...         ...       ...
# 153648        ICU    19997473  27787494  2173-09-30  00:00:00
# 153649        ICU    19997473  27787494  2173-09-30  16:00:00
# 153650        ICU    19997473  27787494  2173-10-01  00:00:00
# 153651        ICU    19997473  27787494  2173-10-01  16:00:00
# 153652        ICU    19997473  27787494  2173-10-02  00:00:00
#
#         Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 0                 73.125                    20.875000
# 1                 75.000                    19.666667
# 2                    NaN                          NaN
# 3                 74.500                    16.250000
# 4                 74.500                    15.250000
# ...                  ...                          ...
# 153648               NaN                          NaN
# 153649               NaN                          NaN
# 153650               NaN                          NaN
# 153651               NaN                          NaN
# 153652               NaN                          NaN
#
#         O2 saturation pulseoxymetry (%)  \
# 0                                99.625
# 1                                97.000
# 2                                   NaN
# 3                                94.250
# 4                                91.250
# ...                                 ...
# 153648                              NaN
# 153649                              NaN
# 153650                              NaN
# 153651                              NaN
# 153652                              NaN
#
#         Non Invasive Blood Pressure mean (mmHg)  \
# 0                                    100.750000
# 1                                     89.000000
# 2                                           NaN
# 3                                           NaN
# 4                                     75.142857
# ...                                         ...
# 153648                                      NaN
# 153649                                      NaN
# 153650                                      NaN
# 153651                                      NaN
# 153652                                      NaN
#
#         Non Invasive Blood Pressure systolic (mmHg)  ...  \
# 0                                        146.625000  ...
# 1                                        131.333333  ...
# 2                                               NaN  ...
# 3                                               NaN  ...
# 4                                        120.142857  ...
# ...                                             ...  ...
# 153648                                          NaN  ...
# 153649                                          NaN  ...
# 153650                                          NaN  ...
# 153651                                          NaN  ...
# 153652                                          NaN  ...
#
#         Polys (Cerebrospinal Fluid)  Promyelocytes (Cerebrospinal Fluid)  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 153648                          NaN                                  NaN
# 153649                          NaN                                  NaN
# 153650                          NaN                                  NaN
# 153651                          NaN                                  NaN
# 153652                          NaN                                  NaN
#
#         RBC, CSF (Cerebrospinal Fluid)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 153648                             NaN
# 153649                             NaN
# 153650                             NaN
# 153651                             NaN
# 153652                             NaN
#
#         Total Nucleated Cells, CSF (Cerebrospinal Fluid)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 153648                                               NaN
# 153649                                               NaN
# 153650                                               NaN
# 153651                                               NaN
# 153652                                               NaN
#
#         Total Nucleated Cells, Joint (Joint Fluid)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 153648                                         NaN
# 153649                                         NaN
# 153650                                         NaN
# 153651                                         NaN
# 153652                                         NaN
#
#         Lining Cell (Other Body Fluid)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 153648                             NaN
# 153649                             NaN
# 153650                             NaN
# 153651                             NaN
# 153652                             NaN
#
#         Total Nucleated Cells, Other (Other Body Fluid)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 153648                                              NaN
# 153649                                              NaN
# 153650                                              NaN
# 153651                                              NaN
# 153652                                              NaN
#
#         Total Nucleated Cells, Pleural (Pleural)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 153648                                       NaN
# 153649                                       NaN
# 153650                                       NaN
# 153651                                       NaN
# 153652                                       NaN
#
#         Absolute Lymphocyte Count (Blood).1  hospital_expire_flag
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 153648                                  NaN                   NaN
# 153649                                  NaN                   NaN
# 153650                                  NaN                   NaN
# 153651                                  NaN                   NaN
# 153652                                  NaN                   NaN
#
# [153653 rows x 1359 columns]

# %%
# Εισάγω την τιμή μηδέν στα κενά κελιά της hospital_expire_flag
df_rslt[['hospital_expire_flag']] = df_rslt[['hospital_expire_flag']].fillna(0)

# Μετατρέπω την στήλη hospital_expire_flag σε ακέραιο.
df_rslt['hospital_expire_flag'] = df_rslt['hospital_expire_flag'].apply(int)

# %%
"""
Αντικατάσταση τιμών από μηδέν σε
survival και από ένα σε death
στην στήλη hospital_expire_flag
"""

#df_rslt = df_rslt["hospital_expire_flag"].replace({0 : "survival", 1 :"death"}, inplace = True)


df_rslt["hospital_expire_flag"] = np.where(df_rslt["hospital_expire_flag"] == 0, "survival", "death")

# %%
#Εξαγωγή σε csv
df_rslt.to_csv('D:\Thesis\exports\o31_ICU_final.csv', index=False)
