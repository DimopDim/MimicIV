# %%
import pandas as pd

# %%
df_chart_tbl = pd.read_csv('D:\Papers\Cyprus_Paper\Data\o34_empty_lab_std_tbl.csv', index_col=False)
df_mean_chart = pd.read_csv('D:\Papers\Cyprus_Paper\Data\o29_labevent_24_hour_std.csv', index_col=False)
df_data_chart = pd.read_csv('D:\MSc Aegean\Thesis\mimic-iv-1.0\hosp\d_labitems.csv.gz')

# %%
"""
Δημιουργώ εκ νέου την στήλη concat
χωρίς κενά ανάμεσα στα στοιχεία.
Θα χρησιμοποιήσω αυτή τη στήλη σαν
index γιατί τα κενά μπορεί να
δημιουργήσουν πρόβλημα.
"""
df_chart_tbl["concat"] = (df_chart_tbl["subject_id"].astype(str)
                          + df_chart_tbl["hadm_id"].astype(str)
                          + df_chart_tbl["charttime"].astype(str))

"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace('-','')
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace(':','')

# %%
# Ορίζω την στήλη concat ως index των γραμμών
df_chart_tbl = df_chart_tbl.set_index('concat')

# %%
"""
Δημιουργώ την στήλη concat και στον πίνακα
που περιλαμβάνει τις μετρήσεις για να είναι
το κοινό σημείο ανάμεσα στους δυο πίνακες
"""
df_mean_chart["concat"] = (df_mean_chart["subject_id"].astype(str)
                           + df_mean_chart["hadm_id"].astype(str)
                           + df_mean_chart["charttime"].astype(str))


"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_mean_chart['concat'] = df_mean_chart['concat'].str.replace('-','')
df_mean_chart['concat'] = df_mean_chart['concat'].str.replace(':','')

# %%
# Γεμίζω τον πίνακα
for row in df_mean_chart.itertuples():
    con = row.concat
    item = row.itemid
    value = row.StdDev_Lab
    df_chart_tbl.at['{}'.format(con), '{}'.format(item)] = value

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τους κωδικούς των παρατηρήσεων
df_chart_tbl.to_csv('D:\Papers\Cyprus_Paper\Data\o42_fill_lab_std_itemid_header_tbl.csv', index=False)

# %%
df_data_chart = df_data_chart.set_index('itemid')

# %%
# Ενοποίηση τιμών σε κελιά
df_data_chart["header"] = ("Std Dev - "
                           + df_data_chart["label"].astype(str)
                           + " ("
                           + df_data_chart["fluid"].astype(str)
                           + ")")

# %%
"""
Ελέγχω τις κεφαλίδες και αν δεν ανήκουν στις
τέσσερις πρώτες τιμές κάνω τις αντικατάσταση.
"""
for col in df_chart_tbl.columns:
    if ((col != 'subject_id') and
        (col != 'hadm_id') and
        (col != 'charttime')):
        temp = (df_data_chart.loc[int(col), 'header'])
        df_chart_tbl.rename(columns={'{}'.format(col): '{}'.format(temp)}, inplace=True)

# %%
df_chart_tbl
# Out:
#                           subject_id   hadm_id   charttime  \
# concat
# 100047332741187621741204    10004733  27411876  2174-12-04
# 100047332741187621741205    10004733  27411876  2174-12-05
# 100047332741187621741206    10004733  27411876  2174-12-06
# 100047332741187621741207    10004733  27411876  2174-12-07
# 100047332741187621741208    10004733  27411876  2174-12-08
# ...                              ...       ...         ...
# 199999872386574521451104    19999987  23865745  2145-11-04
# 199999872386574521451105    19999987  23865745  2145-11-05
# 199999872386574521451106    19999987  23865745  2145-11-06
# 199999872386574521451109    19999987  23865745  2145-11-09
# 199999872386574521451107    19999987  23865745  2145-11-07
#
#                           Std Dev - Potassium (Blood)  \
# concat
# 100047332741187621741204                     0.212132
# 100047332741187621741205                     0.353553
# 100047332741187621741206                          NaN
# 100047332741187621741207                     0.070711
# 100047332741187621741208                          NaN
# ...                                               ...
# 199999872386574521451104                          NaN
# 199999872386574521451105                          NaN
# 199999872386574521451106                          NaN
# 199999872386574521451109                          NaN
# 199999872386574521451107                          NaN
#
#                           Std Dev - Creatinine (Blood)  \
# concat
# 100047332741187621741204                      0.000000
# 100047332741187621741205                      0.212132
# 100047332741187621741206                           NaN
# 100047332741187621741207                      0.000000
# 100047332741187621741208                           NaN
# ...                                                ...
# 199999872386574521451104                           NaN
# 199999872386574521451105                           NaN
# 199999872386574521451106                           NaN
# 199999872386574521451109                           NaN
# 199999872386574521451107                           NaN
#
#                           Std Dev - Urea Nitrogen (Blood)  \
# concat
# 100047332741187621741204                         0.000000
# 100047332741187621741205                         0.707107
# 100047332741187621741206                              NaN
# 100047332741187621741207                         0.707107
# 100047332741187621741208                              NaN
# ...                                                   ...
# 199999872386574521451104                              NaN
# 199999872386574521451105                              NaN
# 199999872386574521451106                              NaN
# 199999872386574521451109                              NaN
# 199999872386574521451107                              NaN
#
#                           Std Dev - Chloride (Blood)  \
# concat
# 100047332741187621741204                    0.707107
# 100047332741187621741205                    0.707107
# 100047332741187621741206                         NaN
# 100047332741187621741207                    0.000000
# 100047332741187621741208                         NaN
# ...                                              ...
# 199999872386574521451104                         NaN
# 199999872386574521451105                         NaN
# 199999872386574521451106                         NaN
# 199999872386574521451109                         NaN
# 199999872386574521451107                         NaN
#
#                           Std Dev - Sodium (Blood)  \
# concat
# 100047332741187621741204                  1.414214
# 100047332741187621741205                  1.414214
# 100047332741187621741206                       NaN
# 100047332741187621741207                  0.707107
# 100047332741187621741208                       NaN
# ...                                            ...
# 199999872386574521451104                       NaN
# 199999872386574521451105                       NaN
# 199999872386574521451106                       NaN
# 199999872386574521451109                       NaN
# 199999872386574521451107                       NaN
#
#                           Std Dev - Bicarbonate (Blood)  \
# concat
# 100047332741187621741204                       1.414214
# 100047332741187621741205                       3.535534
# 100047332741187621741206                            NaN
# 100047332741187621741207                       1.414214
# 100047332741187621741208                            NaN
# ...                                                 ...
# 199999872386574521451104                            NaN
# 199999872386574521451105                            NaN
# 199999872386574521451106                            NaN
# 199999872386574521451109                            NaN
# 199999872386574521451107                            NaN
#
#                           Std Dev - Anion Gap (Blood)  ...  \
# concat                                                 ...
# 100047332741187621741204                     2.828427  ...
# 100047332741187621741205                     3.535534  ...
# 100047332741187621741206                          NaN  ...
# 100047332741187621741207                     0.707107  ...
# 100047332741187621741208                          NaN  ...
# ...                                               ...  ...
# 199999872386574521451104                          NaN  ...
# 199999872386574521451105                          NaN  ...
# 199999872386574521451106                          NaN  ...
# 199999872386574521451109                          NaN  ...
# 199999872386574521451107                          NaN  ...
#
#                           Std Dev - Myelocytes (Cerebrospinal Fluid)  \
# concat
# 100047332741187621741204                                         NaN
# 100047332741187621741205                                         NaN
# 100047332741187621741206                                         NaN
# 100047332741187621741207                                         NaN
# 100047332741187621741208                                         NaN
# ...                                                              ...
# 199999872386574521451104                                         NaN
# 199999872386574521451105                                         NaN
# 199999872386574521451106                                         NaN
# 199999872386574521451109                                         NaN
# 199999872386574521451107                                         NaN
#
#                           Std Dev - Promyelocytes (Pleural)  \
# concat
# 100047332741187621741204                                NaN
# 100047332741187621741205                                NaN
# 100047332741187621741206                                NaN
# 100047332741187621741207                                NaN
# 100047332741187621741208                                NaN
# ...                                                     ...
# 199999872386574521451104                                NaN
# 199999872386574521451105                                NaN
# 199999872386574521451106                                NaN
# 199999872386574521451109                                NaN
# 199999872386574521451107                                NaN
#
#                           Std Dev - Non-squamous Epithelial Cells (Urine)  \
# concat
# 100047332741187621741204                                              NaN
# 100047332741187621741205                                              NaN
# 100047332741187621741206                                              NaN
# 100047332741187621741207                                              NaN
# 100047332741187621741208                                              NaN
# ...                                                                   ...
# 199999872386574521451104                                              NaN
# 199999872386574521451105                                              NaN
# 199999872386574521451106                                              NaN
# 199999872386574521451109                                              NaN
# 199999872386574521451107                                              NaN
#
#                           Std Dev - RBC Casts (Urine)  Std Dev - L (Blood)  \
# concat
# 100047332741187621741204                          NaN                  NaN
# 100047332741187621741205                          NaN                  NaN
# 100047332741187621741206                          NaN                  NaN
# 100047332741187621741207                          NaN                  NaN
# 100047332741187621741208                          NaN                  NaN
# ...                                               ...                  ...
# 199999872386574521451104                          NaN                  NaN
# 199999872386574521451105                          NaN                  NaN
# 199999872386574521451106                          NaN                  NaN
# 199999872386574521451109                          NaN                  NaN
# 199999872386574521451107                          NaN                  NaN
#
#                           Std Dev - Young Cells (Blood)  \
# concat
# 100047332741187621741204                            NaN
# 100047332741187621741205                            NaN
# 100047332741187621741206                            NaN
# 100047332741187621741207                            NaN
# 100047332741187621741208                            NaN
# ...                                                 ...
# 199999872386574521451104                            NaN
# 199999872386574521451105                            NaN
# 199999872386574521451106                            NaN
# 199999872386574521451109                            NaN
# 199999872386574521451107                            NaN
#
#                           Std Dev - NRBC (Joint Fluid)  Std Dev - H (Blood)  \
# concat
# 100047332741187621741204                           NaN                  NaN
# 100047332741187621741205                           NaN                  NaN
# 100047332741187621741206                           NaN                  NaN
# 100047332741187621741207                           NaN                  NaN
# 100047332741187621741208                           NaN                  NaN
# ...                                                ...                  ...
# 199999872386574521451104                           NaN                  NaN
# 199999872386574521451105                           NaN                  NaN
# 199999872386574521451106                           NaN                  NaN
# 199999872386574521451109                           NaN                  NaN
# 199999872386574521451107                           NaN                  NaN
#
#                           Std Dev - DHEA-Sulfate (Blood)  \
# concat
# 100047332741187621741204                             NaN
# 100047332741187621741205                             NaN
# 100047332741187621741206                             NaN
# 100047332741187621741207                             NaN
# 100047332741187621741208                             NaN
# ...                                                  ...
# 199999872386574521451104                             NaN
# 199999872386574521451105                             NaN
# 199999872386574521451106                             NaN
# 199999872386574521451109                             NaN
# 199999872386574521451107                             NaN
#
#                           Std Dev - Cholesterol, Ascites (Ascites)
# concat
# 100047332741187621741204                                       NaN
# 100047332741187621741205                                       NaN
# 100047332741187621741206                                       NaN
# 100047332741187621741207                                       NaN
# 100047332741187621741208                                       NaN
# ...                                                            ...
# 199999872386574521451104                                       NaN
# 199999872386574521451105                                       NaN
# 199999872386574521451106                                       NaN
# 199999872386574521451109                                       NaN
# 199999872386574521451107                                       NaN
#
# [39412 rows x 391 columns]

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τις ονομασίες των παρατηρήσεων
df_chart_tbl.to_csv('D:\Papers\Cyprus_Paper\Data\o43_fill_std_lab_label_header_tbl.csv', index=False)
