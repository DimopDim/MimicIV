# %%
import matplotlib.pyplot as plt
names = [
    'Min-RDW_Blood',
    'StdDev-InspiredO2Fraction_None',
    'StdDev-O2saturationpulseoxymetry_%',
    'Age',
    'Max-GCS-VerbalResponse_nan',
    'Max-BradenMobility_nan',
    'Mean-BradenFriction/Shear_nan',
    'Min-HeartrateAlarm-High_bpm',
    'Min-RespiratoryRate_Total_insp/min',
    'Mean-GCS-EyeOpening_nan',
    'Ethnicity'
]
values = [
          0.02650561573513783,
          0.20182842806368653,
          0.23722830894290597,
          0.4013635075009716,
          0.4553551938249018,
          0.5352289945634922,
          0.5677877743560258,
          0.6404841111732895,
          0.70166454592341,
          1.0550,
          1.5072
]

plt.figure(figsize=(10, 10))
plt.title('Feature Importance (First 8 Hours)')
plt.barh(names, values)
plt.grid(which='major', axis='x', linestyle='-')
plt.ylabel(' ')
plt.xlabel(' ')
plt.show()

# %%
names = [
    'Max - Tidal Volume (Blood)',
    'Max - Richmond-RAS Scale (nan)',
    'Max - GCS - Eye Opening (nan)',
    'Min - Respiratory Rate (Total) (insp/min)',
    'Min - Braden Nutrition (nan)',
    'Min - Braden Sensory Perception (nan)',
    'Min - RDW (Blood)',
    'Mean - Braden Mobility (nan)',
    'Std Dev - O2 saturation pulseoxymetry (%)',
    'Max - Anion Gap (Blood)',
    'Max - GCS - Verbal Response (nan)',
    'Min - Arterial O2 pressure (mmHg)',
    'Age'
]
values = [
    0.019312126,
    0.027193958,
    0.040462254,
    0.055781845,
    0.164034406,
    0.183262963,
    0.215880799,
    0.29410976,
    0.35353238,
    0.378877408,
    0.586790621,
    0.908457028,
    1.332196013,
]

plt.figure(figsize=(10, 10))
plt.title('Feature Importance (First 24 Hours)')
plt.barh(names, values)
plt.grid(which='major', axis='x', linestyle='-')
plt.ylabel(' ')
plt.xlabel(' ')
plt.show()
