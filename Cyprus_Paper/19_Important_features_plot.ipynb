# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.family':'serif'})
plt.rcParams.update({'font.size': 12})

# %%
names = [
    'Min - RDW Blood',
    'StdDev - Inspired O2 Fraction',
    'StdDev - O2 saturation pulse oxymetry (%)',
    'Age',
    'Max - GCS Verbal Response',
    'Max - Braden Mobility',
    'Mean - Braden Friction/Shear',
    'Min - Heartrate Alarm High (bpm)',
    'Min - Respiratory Rate Total (insp/min)',
    'Mean - GCS Eye Opening',
    'Ethnicity'
]
values = [
          0.02650561573513783,
          0.20182842806368653,
          0.23722830894290597,
          0.4013635075009716,
          0.4553551938249018,
          0.5352289945634922,
          0.5677877743560258,
          0.6404841111732895,
          0.70166454592341,
          1.0550,
          1.5072
]

plt.figure(figsize=(10, 10))
plt.title('Feature Importance (First 8 Hours)', fontsize=30)
plt.barh(names, values)
#plt.grid(which='major', axis='x', linestyle='-')
plt.ylabel(' ')
plt.xlabel(' ')
plt.show()

# %%
names = [
    'Max - Tidal Volume (Blood)',
    'Max - Richmond-RAS Scale',
    'Max - GCS - Eye Opening',
    'Min - Respiratory Rate (Total) (insp/min)',
    'Min - Braden Nutrition',
    'Min - Braden Sensory Perception',
    'Min - RDW (Blood)',
    'Mean - Braden Mobility',
    'Std Dev - O2 saturation pulseoxymetry (%)',
    'Max - Anion Gap (Blood)',
    'Max - GCS - Verbal Response',
    'Min - Arterial O2 pressure (mmHg)',
    'Age'
]
values = [
    0.019312126,
    0.027193958,
    0.040462254,
    0.055781845,
    0.164034406,
    0.183262963,
    0.215880799,
    0.29410976,
    0.35353238,
    0.378877408,
    0.586790621,
    0.908457028,
    1.332196013
]

plt.figure(figsize=(10, 10))
plt.title('Feature Importance (First 24 Hours)', fontsize=30)
plt.barh(names, values)
#plt.grid(which='major', axis='x', linestyle='-')
plt.ylabel(' ')
plt.xlabel(' ')
plt.show()
