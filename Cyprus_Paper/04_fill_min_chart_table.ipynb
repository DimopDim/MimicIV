# %%
import pandas as pd

# %%
df_chart_tbl = pd.read_csv('D:\Papers\Cyprus_Paper\Data\o14_empty_chart_min_tbl.csv', index_col=False)
df_min_chart = pd.read_csv('D:\Papers\Cyprus_Paper\Data\o9_chartevent_24_hour_min.csv', index_col=False)
df_data_chart = pd.read_csv('D:\MSc Aegean\Thesis\mimic-iv-1.0\icu\d_items.csv.gz')

# %%
"""
Δημιουργώ εκ νέου την στήλη concat
χωρίς κενά ανάμεσα στα στοιχεία.
Θα χρησιμοποιήσω αυτή τη στήλη σαν
index γιατί τα κενά μπορεί να
δημιουργήσουν πρόβλημα.
"""
df_chart_tbl["concat"] = (df_chart_tbl["subject_id"].astype(str)
                          + df_chart_tbl["hadm_id"].astype(str)
                          + df_chart_tbl["charttime"].astype(str))

"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace('-','')
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace(':','')

# %%
# Ορίζω την στήλη concat ως index των γραμμών
df_chart_tbl = df_chart_tbl.set_index('concat')

# %%
"""
Δημιουργώ την στήλη concat και στον πίνακα
που περιλαμβάνει τις μετρήσεις για να είναι
το κοινό σημείο ανάμεσα στους δυο πίνακες
"""
df_min_chart["concat"] = (df_min_chart["subject_id"].astype(str)
                           + df_min_chart["hadm_id"].astype(str)
                           + df_min_chart["charttime"].astype(str))


"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_min_chart['concat'] = df_min_chart['concat'].str.replace('-','')
df_min_chart['concat'] = df_min_chart['concat'].str.replace(':','')

# %%
# Γεμίζω τον πίνακα
for row in df_min_chart.itertuples():
    con = row.concat
    item = row.itemid
    value = row.Min_Chart
    df_chart_tbl.at['{}'.format(con), '{}'.format(item)] = value

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τους κωδικούς των παρατηρήσεων
df_chart_tbl.to_csv('D:\Papers\Cyprus_Paper\Data\o19_fill_chart_min_itemid_header_tbl.csv', index=False)

# %%
df_data_chart = df_data_chart.set_index('itemid')

# %%
# Ενοποίηση τιμών σε κελιά
df_data_chart["header"] = ("Min - "
                           + df_data_chart["label"].astype(str)
                           + " ("
                           + df_data_chart["unitname"].astype(str)
                           + ")")

# %%
"""
Ελέγχω τις κεφαλίδες και αν δεν ανήκουν στις
τέσσερις πρώτες τιμές κάνω τις αντικατάσταση.
"""
for col in df_chart_tbl.columns:
    if ((col != 'subject_id') and
        (col != 'hadm_id') and
        (col != 'charttime')):
        temp = (df_data_chart.loc[int(col), 'header'])
        df_chart_tbl.rename(columns={'{}'.format(col): '{}'.format(temp)}, inplace=True)

# %%
df_chart_tbl
# Out:
#                           subject_id   hadm_id   charttime  \
# concat
# 100047332741187621741204    10004733  27411876  2174-12-04
# 100047332741187621741205    10004733  27411876  2174-12-05
# 100047332741187621741206    10004733  27411876  2174-12-06
# 100047332741187621741207    10004733  27411876  2174-12-07
# 100047332741187621741208    10004733  27411876  2174-12-08
# ...                              ...       ...         ...
# 199994422678531721481125    19999442  26785317  2148-11-25
# 199994422678531721481126    19999442  26785317  2148-11-26
# 199999872386574521451102    19999987  23865745  2145-11-02
# 199999872386574521451103    19999987  23865745  2145-11-03
# 199999872386574521451104    19999987  23865745  2145-11-04
#
#                           Min - Heart Rate (bpm)  \
# concat
# 100047332741187621741204                    87.0
# 100047332741187621741205                    75.0
# 100047332741187621741206                    70.0
# 100047332741187621741207                    65.0
# 100047332741187621741208                    71.0
# ...                                          ...
# 199994422678531721481125                    46.0
# 199994422678531721481126                    48.0
# 199999872386574521451102                    94.0
# 199999872386574521451103                    76.0
# 199999872386574521451104                    87.0
#
#                           Min - Respiratory Rate (insp/min)  \
# concat
# 100047332741187621741204                               16.0
# 100047332741187621741205                                8.0
# 100047332741187621741206                                8.0
# 100047332741187621741207                               10.0
# 100047332741187621741208                               15.0
# ...                                                     ...
# 199994422678531721481125                                9.0
# 199994422678531721481126                               11.0
# 199999872386574521451102                               21.0
# 199999872386574521451103                               14.0
# 199999872386574521451104                               14.0
#
#                           Min - O2 saturation pulseoxymetry (%)  \
# concat
# 100047332741187621741204                                   94.0
# 100047332741187621741205                                   90.0
# 100047332741187621741206                                   93.0
# 100047332741187621741207                                   93.0
# 100047332741187621741208                                   92.0
# ...                                                         ...
# 199994422678531721481125                                   95.0
# 199994422678531721481126                                   97.0
# 199999872386574521451102                                   98.0
# 199999872386574521451103                                   93.0
# 199999872386574521451104                                   91.0
#
#                           Min - Non Invasive Blood Pressure systolic (mmHg)  \
# concat
# 100047332741187621741204                                              124.0
# 100047332741187621741205                                              108.0
# 100047332741187621741206                                              108.0
# 100047332741187621741207                                              121.0
# 100047332741187621741208                                              147.0
# ...                                                                     ...
# 199994422678531721481125                                              124.0
# 199994422678531721481126                                              133.0
# 199999872386574521451102                                              115.0
# 199999872386574521451103                                               90.0
# 199999872386574521451104                                              100.0
#
#                           Min - Non Invasive Blood Pressure diastolic (mmHg)  \
# concat
# 100047332741187621741204                                               75.0
# 100047332741187621741205                                               50.0
# 100047332741187621741206                                               60.0
# 100047332741187621741207                                               68.0
# 100047332741187621741208                                               89.0
# ...                                                                     ...
# 199994422678531721481125                                               67.0
# 199994422678531721481126                                               71.0
# 199999872386574521451102                                               70.0
# 199999872386574521451103                                               57.0
# 199999872386574521451104                                               51.0
#
#                           Min - Non Invasive Blood Pressure mean (mmHg)  \
# concat
# 100047332741187621741204                                           90.0
# 100047332741187621741205                                           65.0
# 100047332741187621741206                                           70.0
# 100047332741187621741207                                           78.0
# 100047332741187621741208                                          104.0
# ...                                                                 ...
# 199994422678531721481125                                           82.0
# 199994422678531721481126                                           85.0
# 199999872386574521451102                                           81.0
# 199999872386574521451103                                           65.0
# 199999872386574521451104                                           60.0
#
#                           Min - Arterial Blood Pressure mean (mmHg)  ...  \
# concat                                                               ...
# 100047332741187621741204                                        NaN  ...
# 100047332741187621741205                                        NaN  ...
# 100047332741187621741206                                        NaN  ...
# 100047332741187621741207                                        NaN  ...
# 100047332741187621741208                                        NaN  ...
# ...                                                             ...  ...
# 199994422678531721481125                                        NaN  ...
# 199994422678531721481126                                        NaN  ...
# 199999872386574521451102                                        NaN  ...
# 199999872386574521451103                                        NaN  ...
# 199999872386574521451104                                        NaN  ...
#
#                           Min - Resistance (cmH2O/L/seconds)  \
# concat
# 100047332741187621741204                                 NaN
# 100047332741187621741205                                 NaN
# 100047332741187621741206                                 NaN
# 100047332741187621741207                                 NaN
# 100047332741187621741208                                 NaN
# ...                                                      ...
# 199994422678531721481125                                 NaN
# 199994422678531721481126                                 NaN
# 199999872386574521451102                                 NaN
# 199999872386574521451103                                 NaN
# 199999872386574521451104                                 NaN
#
#                           Min - ABI Ankle BP L (mmHg)  \
# concat
# 100047332741187621741204                          NaN
# 100047332741187621741205                          NaN
# 100047332741187621741206                          NaN
# 100047332741187621741207                          NaN
# 100047332741187621741208                          NaN
# ...                                               ...
# 199994422678531721481125                          NaN
# 199994422678531721481126                          NaN
# 199999872386574521451102                          NaN
# 199999872386574521451103                          NaN
# 199999872386574521451104                          NaN
#
#                           Min - ABI Brachial BP R (mmHg)  \
# concat
# 100047332741187621741204                             NaN
# 100047332741187621741205                             NaN
# 100047332741187621741206                             NaN
# 100047332741187621741207                             NaN
# 100047332741187621741208                             NaN
# ...                                                  ...
# 199994422678531721481125                             NaN
# 199994422678531721481126                             NaN
# 199999872386574521451102                             NaN
# 199999872386574521451103                             NaN
# 199999872386574521451104                             NaN
#
#                           Min - ITBVI (PiCCO) (mL/m2)  \
# concat
# 100047332741187621741204                          NaN
# 100047332741187621741205                          NaN
# 100047332741187621741206                          NaN
# 100047332741187621741207                          NaN
# 100047332741187621741208                          NaN
# ...                                               ...
# 199994422678531721481125                          NaN
# 199994422678531721481126                          NaN
# 199999872386574521451102                          NaN
# 199999872386574521451103                          NaN
# 199999872386574521451104                          NaN
#
#                           Min - Patient/Family Informed_V1 (nan)  \
# concat
# 100047332741187621741204                                     NaN
# 100047332741187621741205                                     NaN
# 100047332741187621741206                                     NaN
# 100047332741187621741207                                     NaN
# 100047332741187621741208                                     NaN
# ...                                                          ...
# 199994422678531721481125                                     NaN
# 199994422678531721481126                                     NaN
# 199999872386574521451102                                     NaN
# 199999872386574521451103                                     NaN
# 199999872386574521451104                                     NaN
#
#                           Min - Pheresis Catheter Line Tip Cultured (nan)  \
# concat
# 100047332741187621741204                                              NaN
# 100047332741187621741205                                              NaN
# 100047332741187621741206                                              NaN
# 100047332741187621741207                                              NaN
# 100047332741187621741208                                              NaN
# ...                                                                   ...
# 199994422678531721481125                                              NaN
# 199994422678531721481126                                              NaN
# 199999872386574521451102                                              NaN
# 199999872386574521451103                                              NaN
# 199999872386574521451104                                              NaN
#
#                           Min - Triple Introducer Line Tip Cultured (nan)  \
# concat
# 100047332741187621741204                                              NaN
# 100047332741187621741205                                              NaN
# 100047332741187621741206                                              NaN
# 100047332741187621741207                                              NaN
# 100047332741187621741208                                              NaN
# ...                                                                   ...
# 199994422678531721481125                                              NaN
# 199994422678531721481126                                              NaN
# 199999872386574521451102                                              NaN
# 199999872386574521451103                                              NaN
# 199999872386574521451104                                              NaN
#
#                           Min - Depth at which wedge obtained (PA Line) (cm)  \
# concat
# 100047332741187621741204                                                NaN
# 100047332741187621741205                                                NaN
# 100047332741187621741206                                                NaN
# 100047332741187621741207                                                NaN
# 100047332741187621741208                                                NaN
# ...                                                                     ...
# 199994422678531721481125                                                NaN
# 199994422678531721481126                                                NaN
# 199999872386574521451102                                                NaN
# 199999872386574521451103                                                NaN
# 199999872386574521451104                                                NaN
#
#                           Min - Clot Size (cm) (cm)  \
# concat
# 100047332741187621741204                        NaN
# 100047332741187621741205                        NaN
# 100047332741187621741206                        NaN
# 100047332741187621741207                        NaN
# 100047332741187621741208                        NaN
# ...                                             ...
# 199994422678531721481125                        NaN
# 199994422678531721481126                        NaN
# 199999872386574521451102                        NaN
# 199999872386574521451103                        NaN
# 199999872386574521451104                        NaN
#
#                           Min - Resting Energy Expenditure (kcal/day)
# concat
# 100047332741187621741204                                          NaN
# 100047332741187621741205                                          NaN
# 100047332741187621741206                                          NaN
# 100047332741187621741207                                          NaN
# 100047332741187621741208                                          NaN
# ...                                                               ...
# 199994422678531721481125                                          NaN
# 199994422678531721481126                                          NaN
# 199999872386574521451102                                          NaN
# 199999872386574521451103                                          NaN
# 199999872386574521451104                                          NaN
#
# [24136 rows x 710 columns]

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τις ονομασίες των παρατηρήσεων
df_chart_tbl.to_csv('D:\Papers\Cyprus_Paper\Data\o20_fill_min_chart_label_header_tbl.csv', index=False)
