# %%
import pandas as pd
import numpy as np

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o31_ICU_final.csv')

# %%
df_1 = df_icu.iloc[:107568,:]
df_2 = df_icu.iloc[107568:,:]

# %%
df_1.tail()
# Out:
#        Department  subject_id   hadm_id        date      time  \
# 107563        ICU    16934201  20511019  2145-03-01  00:00:00
# 107564        ICU    16934201  20511019  2145-03-01  08:00:00
# 107565        ICU    16934201  20511019  2145-03-01  16:00:00
# 107566        ICU    16934201  20511019  2145-03-02  08:00:00
# 107567        ICU    16934201  20511019  2145-03-03  00:00:00
#
#         Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 107563             81.75                       21.000
# 107564             80.00                       23.375
# 107565             78.50                       23.500
# 107566               NaN                          NaN
# 107567               NaN                          NaN
#
#         O2 saturation pulseoxymetry (%)  \
# 107563                            96.75
# 107564                            97.50
# 107565                            94.75
# 107566                              NaN
# 107567                              NaN
#
# ...

# %%
df_2.head()
# Out:
#        Department  subject_id   hadm_id        date      time  \
# 107568        ICU    16934248  27504332  2142-04-17  00:00:00
# 107569        ICU    16934248  27504332  2142-04-17  16:00:00
# 107570        ICU    16934248  27504332  2142-04-18  00:00:00
# 107571        ICU    16934248  27504332  2142-04-19  00:00:00
# 107572        ICU    16934248  27504332  2142-04-19  08:00:00
#
#         Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 107568               NaN                          NaN
# 107569               NaN                          NaN
# 107570               NaN                          NaN
# 107571               NaN                          NaN
# 107572              64.0                         14.0
#
#         O2 saturation pulseoxymetry (%)  \
# 107568                              NaN
# 107569                              NaN
# 107570                              NaN
# 107571                              NaN
# 107572                             94.0
#
# ...

# %%
df_1.to_csv('D:\Thesis\exports\Train_test\Train_70.csv', index=False)
df_2.to_csv('D:\Thesis\exports\Train_test\Test_30.csv', index=False)
