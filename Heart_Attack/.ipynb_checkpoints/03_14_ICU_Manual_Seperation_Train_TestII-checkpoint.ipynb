# %%
import pandas as pd
import numpy as np

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o31_ICU_final.csv')

# %%
df_icu = df_icu.drop(['subject_id', 'hadm_id', 'date', 'time', 'Department'], axis=1)

# %%
df_icu.to_csv('D:\Thesis\exports\o32_ICU_final_without_subject.csv', index=False)

# %%
df1 = df_icu.iloc[:107568]
df2 = df_icu.iloc[107568:]

# %%
df1
# Out:
#        Department  subject_id   hadm_id        date      time  \
# 0             ICU    10000980  26913865  2189-06-27  00:00:00
# 1             ICU    10000980  26913865  2189-06-27  08:00:00
# 2             ICU    10000980  26913865  2189-06-27  16:00:00
# 3             ICU    10000980  26913865  2189-06-28  00:00:00
# 4             ICU    10000980  26913865  2189-06-28  08:00:00
# ...           ...         ...       ...         ...       ...
# 107563        ICU    16934201  20511019  2145-03-01  00:00:00
# 107564        ICU    16934201  20511019  2145-03-01  08:00:00
# 107565        ICU    16934201  20511019  2145-03-01  16:00:00
# 107566        ICU    16934201  20511019  2145-03-02  08:00:00
# 107567        ICU    16934201  20511019  2145-03-03  00:00:00
#
#         Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 0                    NaN                          NaN
# 1                 73.125                    20.875000
# 2                 75.000                    19.666667
# ...

# %%
df_temp1 = df_icu[:107568]
df_temp2 = df_icu[-46085:]

# %%
df1 = df1.drop(['subject_id', 'hadm_id', 'date', 'time', 'Department'], axis=1)

df2 = df2.drop(['subject_id', 'hadm_id', 'date', 'time', 'Department'], axis=1)

# %%
df1.to_csv('D:\Thesis\exports\TrainII_70.csv', index=False)
df2.to_csv('D:\Thesis\exports\TestII_30.csv', index=False)
