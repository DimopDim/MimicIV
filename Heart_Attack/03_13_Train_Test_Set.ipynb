# %% [markdown]
# ## Δημιουργία Train - Test Set (4 αρχεία)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o31_ICU_final.csv')

# %%
y = df_icu.hospital_expire_flag

# %%
x = df_icu.drop('hospital_expire_flag',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
print("shape of original dataset :", df_icu.shape)
print("shape of input - training set", x_train.shape)
print("shape of output - training set", y_train.shape)
print("shape of input - testing set", x_test.shape)
print("shape of output - testing set", y_test.shape)
# Out:
# shape of original dataset : (90817, 1101)
# shape of input - training set (63571, 1100)
# shape of output - training set (63571,)
# shape of input - testing set (27246, 1100)
# shape of output - testing set (27246,)

# %%
#Εξαγωγή σε csv
#Χαλάει την ταξινόμηση
x_train.to_csv('D:\Thesis\exports\Train_Test_Sets\Four_files\o1_xTrain.csv', index=False)
x_test.to_csv('D:\Thesis\exports\Train_Test_Sets\Four_files\o2_xTest.csv', index=False)
y_train.to_csv('D:\Thesis\exports\Train_Test_Sets\Four_files\o3_yTrain.csv', index=False)
y_test.to_csv('D:\Thesis\exports\Train_Test_Sets\Four_files\o1_yTest.csv', index=False)

# %% [markdown]
# ## Δημιουργία Training - Test Set (2 αρχεία)

# %%
df_icu = pd.read_csv('D:\Thesis\exports\o31_ICU_final.csv')

# %%
x_train,x_test=train_test_split(df_icu,test_size=0.3)

# %%
print("shape of original dataset :", df_icu.shape)
print("shape of input - training set", x_train.shape)
# Out:
# shape of original dataset : (153653, 1359)
# shape of input - training set (107557, 1359)

# %%
#Εξαγωγή σε csv
#Χαλάει την ταξινόμηση
x_train.to_csv('D:\Thesis\exports\Train_Test_Sets\o1_xTrain.csv', index=False)
x_test.to_csv('D:\Thesis\exports\Train_Test_Sets\o2_xTest.csv', index=False)

# %% [markdown]
# # Από εδώ και κάτω είναι για την παραγωγή του CSV της Βίκυς

# %%
temp=df_icu.head(63568)

# %%
temp
# Out:
#       Department  subject_id   hadm_id        date      time  \
# 0            ICU    10004733  27411876  2174-12-04  08:00:00
# 1            ICU    10004733  27411876  2174-12-04  16:00:00
# 2            ICU    10004733  27411876  2174-12-05  00:00:00
# 3            ICU    10004733  27411876  2174-12-05  08:00:00
# 4            ICU    10004733  27411876  2174-12-05  16:00:00
# ...          ...         ...       ...         ...       ...
# 63563        ICU    17055144  25353671  2116-06-30  00:00:00
# 63564        ICU    17055144  25353671  2116-06-30  08:00:00
# 63565        ICU    17055144  25353671  2116-07-01  00:00:00
# 63566        ICU    17055144  25353671  2116-07-02  08:00:00
# 63567        ICU    17055144  25353671  2116-07-03  00:00:00
#
#        Heart Rate (bpm)  Respiratory Rate (insp/min)  \
# 0             93.200000                    19.800000
# 1             97.250000                    19.250000
# 2            100.333333                    24.222222
# 3             90.687500                    20.312500
# 4             92.111111                    14.000000
# ...                 ...                          ...
# 63563         90.125000                    17.125000
# 63564         99.125000                    18.750000
# 63565               NaN                          NaN
# 63566               NaN                          NaN
# 63567               NaN                          NaN
#
#        O2 saturation pulseoxymetry (%)  \
# 0                            98.800000
# 1                            96.875000
# 2                            94.444444
# 3                            95.031250
# 4                            96.777778
# ...                                ...
# 63563                        93.375000
# 63564                        94.250000
# 63565                              NaN
# 63566                              NaN
# 63567                              NaN
#
#        Non Invasive Blood Pressure systolic (mmHg)  \
# 0                                       170.750000
# 1                                       153.125000
# 2                                       154.666667
# 3                                       147.031250
# 4                                       148.555556
# ...                                            ...
# 63563                                   115.375000
# 63564                                   125.875000
# 63565                                          NaN
# 63566                                          NaN
# 63567                                          NaN
#
#        Non Invasive Blood Pressure diastolic (mmHg)  ...  \
# 0                                        103.250000  ...
# 1                                         90.250000  ...
# 2                                         75.777778  ...
# 3                                         67.437500  ...
# 4                                         73.666667  ...
# ...                                             ...  ...
# 63563                                     72.000000  ...
# 63564                                     83.000000  ...
# 63565                                           NaN  ...
# 63566                                           NaN  ...
# 63567                                           NaN  ...
#
#        Plasma (Cerebrospinal Fluid)  Polys (Cerebrospinal Fluid)  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 63563                           NaN                          NaN
# 63564                           NaN                          NaN
# 63565                           NaN                          NaN
# 63566                           NaN                          NaN
# 63567                           NaN                          NaN
#
#        Promyelocytes (Cerebrospinal Fluid)  RBC, CSF (Cerebrospinal Fluid)  \
# 0                                      NaN                             NaN
# 1                                      NaN                             NaN
# 2                                      NaN                             NaN
# 3                                      NaN                             NaN
# 4                                      NaN                             NaN
# ...                                    ...                             ...
# 63563                                  NaN                             NaN
# 63564                                  NaN                             NaN
# 63565                                  NaN                             NaN
# 63566                                  NaN                             NaN
# 63567                                  NaN                             NaN
#
#        Total Nucleated Cells, CSF (Cerebrospinal Fluid)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 63563                                               NaN
# 63564                                               NaN
# 63565                                               NaN
# 63566                                               NaN
# 63567                                               NaN
#
#        Total Nucleated Cells, Joint (Joint Fluid)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 63563                                         NaN
# 63564                                         NaN
# 63565                                         NaN
# 63566                                         NaN
# 63567                                         NaN
#
#        Total Nucleated Cells, Other (Other Body Fluid)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 63563                                              NaN
# 63564                                              NaN
# 63565                                              NaN
# 63566                                              NaN
# 63567                                              NaN
#
#        Total Nucleated Cells, Pleural (Pleural)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 63563                                       NaN
# 63564                                       NaN
# 63565                                       NaN
# 63566                                       NaN
# 63567                                       NaN
#
#        Absolute Lymphocyte Count (Blood).1  hospital_expire_flag
# 0                                      NaN              survival
# 1                                      NaN              survival
# 2                                      NaN              survival
# 3                                      NaN              survival
# 4                                      NaN              survival
# ...                                    ...                   ...
# 63563                                  NaN              survival
# 63564                                  NaN              survival
# 63565                                  NaN              survival
# 63566                                  NaN              survival
# 63567                                  NaN              survival
#
# [63568 rows x 1101 columns]

# %%
# εκτυπώνει όλες τις τιμές από τα dataframe.
#pd.set_option('display.max_rows', None)

# %%
temp.to_csv('D:\Thesis\exports\Train_Test_Sets\Manual_files\Test30.csv', index=False)

# %%
temp = pd.read_csv('D:\Thesis\exports\Train_Test_Sets\Manual_files\Test30.csv')

# %%
eight_hours = pd.read_csv('D:\Thesis\exports\Train_Test_Sets\Manual_files\eight_hours_tbl.csv')

# %%
rslt_df=pd.merge(temp, eight_hours, left_index=True, right_index=True)

# %%
# Φέρνω τις τελευταίες στήλες, πρώτες
cols = list(rslt_df.columns)
cols = [cols[-1]] + cols[:-1]
rslt_df = rslt_df[cols]

# %%
tempII = rslt_df.loc[rslt_df['eight_hours'] == 1]

# %%
Final = tempII.drop_duplicates(subset=['subject_id'])

# %%
Final.to_csv('D:\Thesis\exports\Train_Test_Sets\Manual_files\eight_hours_unique.csv', index=False)
