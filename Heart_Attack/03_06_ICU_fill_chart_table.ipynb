# %%
"""
Γεμίζω τον πίνακα με τις μετρήσεις
του chartevet 8ώρου.

Ο πίνακας μου απαρτίζεται από 707
στήλες και 65189 γραμμές, οπότε μου
δημιουργούν 46.088.623 κελιά.

Οι τιμές μου ανέρχονται στα 4.177.458
οπότε με μια αφαίρεση προκείπτουν
41.911.165 NaN κελιά
"""
# Out:
# '\nΓεμίζω τον πίνακα με τις μετρήσεις\nτου chartevet 8ώρου.\n\nΟ πίνακας μου απαρτίζεται από 707\nστήλες και 65189 γραμμές, οπότε μου\nδημιουργούν 46.088.623 κελιά.\n\nΟι τιμές μου ανέρχονται στα 4.177.458\nοπότε με μια αφαίρεση προκείπτουν\n41.911.165 NaN κελιά\n'

# %%
import pandas as pd

# %%
df_chart_tbl = pd.read_csv('D:\Thesis\exports\o10_empty_chart_tbl.csv', index_col=False)
df_mean_chart = pd.read_csv('D:\Thesis\exports\o9_chartevent_8_hour_mean.csv', index_col=False)
df_data_chart = pd.read_csv('D:\Thesis\mimic-iv-1.0\icu\d_items.csv.gz')

# %%
df_chart_tbl
# Out:
#        220045  220210  220277  220181  220179  220180  220052  220050  220051  \
# 0         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 96795     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96796     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96797     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96798     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 96799     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#        224641  ...  227006  227010  227013  227015  227017  227001  \
# 0         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4         NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...       ...  ...     ...     ...     ...     ...     ...     ...
# 96795     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 96796     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 96797     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 96798     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 96799     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#        subject_id   hadm_id        date      time
# 0        10000980  26913865  2189-06-27  08:00:00
# 1        10000980  26913865  2189-06-27  16:00:00
# 2        10000980  26913865  2189-06-27  00:00:00
# 3        10002155  23822395  2129-08-04  08:00:00
# 4        10002155  23822395  2129-08-04  16:00:00
# ...           ...       ...         ...       ...
# 96795    19997473  27787494  2173-09-20  16:00:00
# 96796    19997473  27787494  2173-09-21  00:00:00
# 96797    19997473  27787494  2173-09-21  08:00:00
# 96798    19997473  27787494  2173-09-21  16:00:00
# 96799    19997473  27787494  2173-09-22  00:00:00
#
# [96800 rows x 905 columns]

# %%
# Φέρνω τις τελευταίες στήλες, πρώτες
for i in range (1, 5):
    cols = list(df_chart_tbl.columns)
    cols = [cols[-1]] + cols[:-1]
    df_chart_tbl = df_chart_tbl[cols]

# %%
# Ελέγχω αν υπάρχει NaN στην στήλη με τις μέσες τιμές, το αποτέλεσμα ισούται με μηδέν.
df_mean_chart['Mean_Chart'].isna().sum()
# Out:
# 0

# %%
"""
Δημιουργώ εκ νέου την στήλη concat
χωρίς κενά ανάμεσα στα στοιχεία.
Θα χρησιμοποιήσω αυτή τη στήλη σαν
index γιατί τα κενά μπορεί να
δημιουργήσουν πρόβλημα.
"""
df_chart_tbl["concat"] = (df_chart_tbl["subject_id"].astype(str)
                          + df_chart_tbl["hadm_id"].astype(str)
                          + df_chart_tbl["date"].astype(str)
                          + df_chart_tbl["time"].astype(str))

"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace('-','')
df_chart_tbl['concat'] = df_chart_tbl['concat'].str.replace(':','')

# %%
# Ορίζω την στήλη concat ως index των γραμμών
df_chart_tbl = df_chart_tbl.set_index('concat')

# %%
"""
Δημιουργώ την στήλη concat και στον πίνακα
που περιλαμβάνει τις μετρήσεις για να είναι
το κοινό σημείο ανάμεσα στους δυο πίνακες
"""
df_mean_chart["concat"] = (df_mean_chart["subject_id"].astype(str)
                           + df_mean_chart["hadm_id"].astype(str)
                           + df_mean_chart["date"].astype(str)
                           + df_mean_chart["time"].astype(str))


"""
Αφαιρώ τους χαρακτήρες - και :
από της τιμές της concat για να
αποφύγω πιθανά προβλήματα
"""
df_mean_chart['concat'] = df_mean_chart['concat'].str.replace('-','')
df_mean_chart['concat'] = df_mean_chart['concat'].str.replace(':','')

# %%
# Γεμίζω τον πίνακα
for row in df_mean_chart.itertuples():
    con = row.concat
    item = row.itemid
    value = row.Mean_Chart
    df_chart_tbl.at['{}'.format(con), '{}'.format(item)] = value

# %%
# Κενά κελιά
df_chart_tbl.isna().sum().sum()
# Out:
# 80470790

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τους κωδικούς των παρατηρήσεων
df_chart_tbl.to_csv('D:\Thesis\exports\o11_fill_chart_itemid_header_tbl.csv', index=False)

# %%
df_data_chart = df_data_chart.set_index('itemid')

# %%
df_data_chart
# Out:
#                             label               abbreviation         linksto  \
# itemid
# 220003         ICU Admission date         ICU Admission date  datetimeevents
# 220045                 Heart Rate                         HR     chartevents
# 220046    Heart rate Alarm - High            HR Alarm - High     chartevents
# 220047     Heart Rate Alarm - Low             HR Alarm - Low     chartevents
# 220048               Heart Rhythm               Heart Rhythm     chartevents
# ...                           ...                        ...             ...
# 229355  Absolute Neutrophil Count  Absolute Neutrophil Count     chartevents
# 229453                 Exam-GI/GU                 Exam-GI/GU     chartevents
# 229604            Therapeutic Bed            Therapeutic Bed     chartevents
# 229709  Angiotensin II (Giapreza)  Angiotensin II (Giapreza)     inputevents
# 229836      Low Speed Limit (VAD)      Low Speed Limit (VAD)     chartevents
#
#                    category unitname     param_type  lownormalvalue  \
# itemid
# 220003                  ADT      NaN  Date and time             NaN
# 220045  Routine Vital Signs      bpm        Numeric             NaN
# 220046               Alarms      bpm        Numeric             NaN
# 220047               Alarms      bpm        Numeric             NaN
# 220048  Routine Vital Signs      NaN           Text             NaN
# ...                     ...      ...            ...             ...
# 229355                 Labs     None        Numeric             NaN
# 229453     MD Progress Note      NaN           Text             NaN
# 229604           Treatments      NaN           Text             NaN
# 229709          Medications       mg       Solution             NaN
# 229836          Durable VAD      NaN           Text             NaN
#
#         highnormalvalue
# itemid
# 220003              NaN
# 220045              NaN
# 220046              NaN
# 220047              NaN
# 220048              NaN
# ...                 ...
# 229355              NaN
# 229453              NaN
# 229604              NaN
# 229709              NaN
# 229836              NaN
#
# [3861 rows x 8 columns]

# %%
df_chart_tbl
# Out:
#                                 subject_id   hadm_id        date      time  \
# concat
# 100009802691386521890627080000    10000980  26913865  2189-06-27  08:00:00
# 100009802691386521890627160000    10000980  26913865  2189-06-27  16:00:00
# 100009802691386521890627000000    10000980  26913865  2189-06-27  00:00:00
# 100021552382239521290804080000    10002155  23822395  2129-08-04  08:00:00
# 100021552382239521290804160000    10002155  23822395  2129-08-04  16:00:00
# ...                                    ...       ...         ...       ...
# 199974732778749421730920160000    19997473  27787494  2173-09-20  16:00:00
# 199974732778749421730921000000    19997473  27787494  2173-09-21  00:00:00
# 199974732778749421730921080000    19997473  27787494  2173-09-21  08:00:00
# 199974732778749421730921160000    19997473  27787494  2173-09-21  16:00:00
# 199974732778749421730922000000    19997473  27787494  2173-09-22  00:00:00
#
#                                    220045     220210     220277      220181  \
# concat
# 100009802691386521890627080000  73.125000  20.875000  99.625000  100.750000
# 100009802691386521890627160000  75.000000  19.666667  97.000000   89.000000
# 100009802691386521890627000000        NaN        NaN        NaN         NaN
# 100021552382239521290804080000  74.500000  16.250000  94.250000         NaN
# 100021552382239521290804160000  74.500000  15.250000  91.250000   75.142857
# ...                                   ...        ...        ...         ...
# 199974732778749421730920160000  79.125000  17.750000  93.875000   61.142857
# 199974732778749421730921000000  76.875000  22.500000  92.875000   59.166667
# 199974732778749421730921080000  72.555556  15.777778  96.555556   66.777778
# 199974732778749421730921160000  66.500000  17.500000  96.375000   61.500000
# 199974732778749421730922000000  65.285714  15.142857  92.285714   62.571429
#
#                                     220179     220180  ...  226999  227000  \
# concat                                                 ...
# 100009802691386521890627080000  146.625000  86.500000  ...     NaN     NaN
# 100009802691386521890627160000  131.333333  74.666667  ...     NaN     NaN
# 100009802691386521890627000000         NaN        NaN  ...     NaN     NaN
# 100021552382239521290804080000         NaN        NaN  ...     NaN     NaN
# 100021552382239521290804160000  120.142857  62.285714  ...     NaN     NaN
# ...                                    ...        ...  ...     ...     ...
# 199974732778749421730920160000  100.857143  49.142857  ...     NaN     NaN
# 199974732778749421730921000000   94.500000  48.666667  ...     NaN     NaN
# 199974732778749421730921080000  105.222222  55.111111  ...     NaN     NaN
# 199974732778749421730921160000   97.875000  50.375000  ...     NaN     NaN
# 199974732778749421730922000000   97.142857  52.000000  ...     NaN     NaN
#
#                                 227004  227005  227006  227010  227013  \
# concat
# 100009802691386521890627080000     NaN     NaN     NaN     NaN     NaN
# 100009802691386521890627160000     NaN     NaN     NaN     NaN     NaN
# 100009802691386521890627000000     NaN     NaN     NaN     NaN     NaN
# 100021552382239521290804080000     NaN     NaN     NaN     NaN     NaN
# 100021552382239521290804160000     NaN     NaN     NaN     NaN     NaN
# ...                                ...     ...     ...     ...     ...
# 199974732778749421730920160000     NaN     NaN     NaN     NaN     NaN
# 199974732778749421730921000000     NaN     NaN     NaN     NaN     NaN
# 199974732778749421730921080000     NaN     NaN     NaN     NaN     NaN
# 199974732778749421730921160000     NaN     NaN     NaN     NaN     NaN
# 199974732778749421730922000000     NaN     NaN     NaN     NaN     NaN
#
#                                 227015  227017  227001
# concat
# 100009802691386521890627080000     NaN     NaN     NaN
# 100009802691386521890627160000     NaN     NaN     NaN
# 100009802691386521890627000000     NaN     NaN     NaN
# 100021552382239521290804080000     NaN     NaN     NaN
# 100021552382239521290804160000     NaN     NaN     NaN
# ...                                ...     ...     ...
# 199974732778749421730920160000     NaN     NaN     NaN
# 199974732778749421730921000000     NaN     NaN     NaN
# 199974732778749421730921080000     NaN     NaN     NaN
# 199974732778749421730921160000     NaN     NaN     NaN
# 199974732778749421730922000000     NaN     NaN     NaN
#
# [96800 rows x 905 columns]

# %%
# Ενοποίηση τιμών σε κελιά
df_data_chart["header"] = (df_data_chart["label"].astype(str)
                           + " ("
                           + df_data_chart["unitname"].astype(str)
                           + ")")

# %%
"""
Ελέγχω τις κεφαλίδες και αν δεν ανήκουν στις
τέσσερις πρώτες τιμές κάνω τις αντικατάσταση.
"""
for col in df_chart_tbl.columns:
    if ((col != 'subject_id') and
        (col != 'hadm_id') and
        (col != 'date') and
        (col != 'time')):
        temp = (df_data_chart.loc[int(col), 'header'])
        df_chart_tbl.rename(columns={'{}'.format(col): '{}'.format(temp)}, inplace=True)

# %%
# Αποθήκευση του τελικού αρχείου με επικεφαλίδες τις ονομασίες των παρατηρήσεων
df_chart_tbl.to_csv('D:\Thesis\exports\o12_fill_chart_label_header_tbl.csv', index=False)
