# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
df_patients_chart = pd.read_csv('D:\Thesis\exports\o7_patient_chartevent_without_nan.csv')

# %%
test = pd.read_csv('D:\MSc Aegean\Thesis\mimic-iv-1.0\icu\d_items.csv')

# %%
test.sort_values(by=['label'])
# Out:
#       itemid                                              label  \
# 3144  229659                                    % Minute Volume
# 2019  228008                            14 G Infiltration Scale
# 2018  228007                               14 G Phlebitis Scale
# 573   224566                                           14 Gauge
# 3211  229736                                14 Gauge Cap Change
# 3205  229730                           14 Gauge Dressing Change
# 1741  227365                        14 Gauge Dressing Occlusive
# 1154  225757                            14 Gauge Insertion Date
# 889   225239                       14 Gauge Reason Discontinued
# 3531  225240                               14 Gauge Site Appear
# 1377  226135                14 Gauge placed in outside facility
# 2105  228097                       14 Gauge placed in the field
# 2021  228010                            16 G Infiltration Scale
# 2020  228009                               16 G Phlebitis Scale
# ...

# %%
df_patients_chart.loc[(df_patients_chart['subject_id'] == 10357189) & (df_patients_chart['itemid'] ==220045)]
# Out:
#      subject_id   hadm_id   stay_id            charttime            storetime  \
# 20     10357189  23179921  32535724  2124-08-01 22:15:00  2124-08-01 22:18:00
# 27     10357189  23179921  32535724  2124-08-01 22:30:00  2124-08-01 22:38:00
# 48     10357189  23179921  32535724  2124-08-01 23:00:00  2124-08-01 23:23:00
# 78     10357189  23179921  32535724  2124-08-02 00:00:00  2124-08-02 00:07:00
# 98     10357189  23179921  32535724  2124-08-02 01:00:00  2124-08-02 01:10:00
# 105    10357189  23179921  32535724  2124-08-02 02:00:00  2124-08-02 02:06:00
# 112    10357189  23179921  32535724  2124-08-02 03:00:00  2124-08-02 03:52:00
# 119    10357189  23179921  32535724  2124-08-02 04:00:00  2124-08-02 04:34:00
# 139    10357189  23179921  32535724  2124-08-02 05:00:00  2124-08-02 05:39:00
# 166    10357189  23179921  32535724  2124-08-02 06:00:00  2124-08-02 06:17:00
# 171    10357189  23179921  32535724  2124-08-02 08:00:00  2124-08-02 08:28:00
# ...
