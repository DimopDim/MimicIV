# %%
import pandas as pd

# %%
df_lab_tbl = pd.read_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\TestII.csv', index_col=False)
df_grouped_cerebral_infarction = pd.read_csv('D:\MSc Aegean\Διατριβή\MIMIC_IV\mimic-iv-1.0\exports\Test.csv', index_col=False)

# %%
df_lab_tbl
# Out:
#     subject_id   hadm_id        date      time  \
# 0     10004733  27411876  2174-12-04  16:00:00
# 1     10004733  27411876  2174-12-04  08:00:00
# 2     10004733  27411876  2174-12-05  16:00:00
# 3     10004733  27411876  2174-12-06  00:00:00
# 4     10004733  27411876  2174-12-07  00:00:00
# ..         ...       ...         ...       ...
# 95    10035817  24176466  2115-09-10  00:00:00
# 96    10035817  24176466  2115-09-11  00:00:00
# 97    10035817  24176466  2115-09-12  00:00:00
# 98    10035817  24176466  2115-09-13  00:00:00
# 99    10035817  24176466  2115-09-13  08:00:00
#
#                                    concat  50801  50802  50803  50804  50805  \
# 0   10004733 27411876 2174-12-04 16:00:00    NaN    NaN    NaN    NaN    NaN
# 1   10004733 27411876 2174-12-04 08:00:00    NaN    NaN    NaN    NaN    NaN
# 2   10004733 27411876 2174-12-05 16:00:00    NaN    NaN    NaN    NaN    NaN
# 3   10004733 27411876 2174-12-06 00:00:00    NaN    NaN    NaN    NaN    NaN
# ...

# %%
df_lab_tbl = df_lab_tbl.drop('concat', 1)

# %%
df_lab_tbl.insert(0,'concat','')
df_lab_tbl["concat"] = df_lab_tbl["subject_id"].astype(str) + df_lab_tbl["hadm_id"].astype(str) + df_lab_tbl["date"].astype(str) + df_lab_tbl["time"].astype(str)

# %%
df_lab_tbl = df_lab_tbl['concat'].astype(str)

# %%
df_lab_tbl
# Out:
#                                     subject_id   hadm_id        date  \
# concat
# 10004733274118762174-12-0416:00:00    10004733  27411876  2174-12-04
# 10004733274118762174-12-0408:00:00    10004733  27411876  2174-12-04
# 10004733274118762174-12-0516:00:00    10004733  27411876  2174-12-05
# 10004733274118762174-12-0600:00:00    10004733  27411876  2174-12-06
# 10004733274118762174-12-0700:00:00    10004733  27411876  2174-12-07
# ...                                        ...       ...         ...
# 10035817241764662115-09-1000:00:00    10035817  24176466  2115-09-10
# 10035817241764662115-09-1100:00:00    10035817  24176466  2115-09-11
# 10035817241764662115-09-1200:00:00    10035817  24176466  2115-09-12
# 10035817241764662115-09-1300:00:00    10035817  24176466  2115-09-13
# 10035817241764662115-09-1308:00:00    10035817  24176466  2115-09-13
#
#                                         time  50801  50802  50803  50804  \
# concat
# ...

# %%
df_lab_tbl = df_lab_tbl.set_index('concat')

# %%
df_lab_tbl.at['10004733274118762174-12-0416:00:00', '50801'] = 30

# %%
df_grouped_cerebral_infarction
# Out:
#       subject_id   hadm_id            charttime        date      time  itemid  \
# 0       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50802
# 1       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50804
# 2       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50812
# 3       10004733  27411876  2174-12-04 08:00:00  2174-12-04  08:00:00   50813
# 4       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50813
# ...          ...       ...                  ...         ...       ...     ...
# 1495    10027602  28166872  2201-11-04 00:00:00  2201-11-04  00:00:00   51301
# 1496    10027602  28166872  2201-11-05 00:00:00  2201-11-05  00:00:00   51301
# 1497    10027602  28166872  2201-11-06 00:00:00  2201-11-06  00:00:00   51301
# 1498    10027602  28166872  2201-11-07 00:00:00  2201-11-07  00:00:00   51301
# 1499    10027602  28166872  2201-11-08 00:00:00  2201-11-08  00:00:00   51301
#
#       8 Hours Mean Lab
# ...

# %%
df_grouped_cerebral_infarction = df_grouped_cerebral_infarction.rename(columns={"8 Hours Mean Lab": "Mean_Lab"})

# %%
df_grouped_cerebral_infarction
# Out:
#       subject_id   hadm_id            charttime        date      time  itemid  \
# 0       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50802
# 1       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50804
# 2       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50812
# 3       10004733  27411876  2174-12-04 08:00:00  2174-12-04  08:00:00   50813
# 4       10004733  27411876  2174-12-04 16:00:00  2174-12-04  16:00:00   50813
# ...          ...       ...                  ...         ...       ...     ...
# 1495    10027602  28166872  2201-11-04 00:00:00  2201-11-04  00:00:00   51301
# 1496    10027602  28166872  2201-11-05 00:00:00  2201-11-05  00:00:00   51301
# 1497    10027602  28166872  2201-11-06 00:00:00  2201-11-06  00:00:00   51301
# 1498    10027602  28166872  2201-11-07 00:00:00  2201-11-07  00:00:00   51301
# 1499    10027602  28166872  2201-11-08 00:00:00  2201-11-08  00:00:00   51301
#
#       Mean_Lab
# 0          0.0
# ...

# %%
df_grouped_cerebral_infarction.insert(0,'concat','')
df_grouped_cerebral_infarction["concat"] = df_grouped_cerebral_infarction["subject_id"].astype(str) + df_grouped_cerebral_infarction["hadm_id"].astype(str) + df_grouped_cerebral_infarction["date"].astype(str) + df_grouped_cerebral_infarction["time"].astype(str)

# %%
df_grouped_cerebral_infarction
# Out:
#                                   concat  subject_id   hadm_id  \
# 0     10004733274118762174-12-0416:00:00    10004733  27411876
# 1     10004733274118762174-12-0416:00:00    10004733  27411876
# 2     10004733274118762174-12-0416:00:00    10004733  27411876
# 3     10004733274118762174-12-0408:00:00    10004733  27411876
# 4     10004733274118762174-12-0416:00:00    10004733  27411876
# ...                                  ...         ...       ...
# 1495  10027602281668722201-11-0400:00:00    10027602  28166872
# 1496  10027602281668722201-11-0500:00:00    10027602  28166872
# 1497  10027602281668722201-11-0600:00:00    10027602  28166872
# 1498  10027602281668722201-11-0700:00:00    10027602  28166872
# 1499  10027602281668722201-11-0800:00:00    10027602  28166872
#
#                 charttime        date      time  itemid  Mean_Lab
# 0     2174-12-04 16:00:00  2174-12-04  16:00:00   50802       0.0
# 1     2174-12-04 16:00:00  2174-12-04  16:00:00   50804      26.0
# ...

# %%
for ind,row in df_grouped_cerebral_infarction.iterrows():
    con = row.concat
    item = row.itemid
    value = row.Mean_Lab
    df_lab_tbl.at['{}'.format(con), '{}'.format(item)] = value
